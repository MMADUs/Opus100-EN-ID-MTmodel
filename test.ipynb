# %%
from datasets import load_dataset

dataset = load_dataset("opus100", "en-id", split="test")  # Already in Parquet
# Out:
# '[Errno 11001] getaddrinfo failed' thrown while requesting HEAD https://huggingface.co/datasets/opus100/resolve/805090dc28bf78897da9641cdf08b61287580df9/opus100.py
# Retrying in 1s [Retry 1/5].
# Using the latest cached version of the dataset since opus100 couldn't be found on the Hugging Face Hub
# Found the latest cached dataset configuration 'en-id' at C:\Users\izbac\.cache\huggingface\datasets\opus100\en-id\0.0.0\805090dc28bf78897da9641cdf08b61287580df9 (last modified on Thu Dec 25 17:41:34 2025).

# %%
print(dataset)
# Out:
# Dataset({
#     features: ['translation'],
#     num_rows: 1000000
# })

# %%
print(dataset['test'])
# Out:
# Dataset({
#     features: ['translation'],
#     num_rows: 2000
# })
